# %% [markdown]
# <a href="https://colab.research.google.com/github/sonti-roy/CTPML/blob/main/Copy_of_Untitled12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests

def get_references_from_doi(doi):
    """
    Retrieves the reference list of a research article given its DOI.

    Args:
        doi (str): The DOI of the research article.

    Returns:
        list: A list of references, or None if an error occurs.
    """
    url = f"https://api.crossref.org/works/{doi}"
    headers = {"accept": "application/json"}
    try:
        response = requests.get(url, headers=headers)
        response.raise_for_status()
        data = response.json()
        references = data['message'].get('reference', [])
        return references
    except requests.exceptions.RequestException as e:
        print(f"Request failed: {e}")
        return None
    except (KeyError, TypeError) as e:
         print(f"Error processing the response: {e}")
         return None

# Example usage:
doi = "10.1371/journal.pone.0321649"
references = get_references_from_doi(doi)

if references:
    for ref in references:
        print(ref)
else:
    print("Could not retrieve references.")
# Out:
# {'issue': 'Pt 2', 'key': 'pone.0321649.ref001', 'doi-asserted-by': 'crossref', 'first-page': '113390', 'DOI': '10.1016/j.foodres.2023.113390', 'article-title': 'Comprehensive evaluation of nutritional components, bioactive metabolites, and antioxidant activities in diverse sorghum (Sorghum bicolor (L.) Moench) landraces', 'volume': '173', 'author': 'KT Desta', 'year': '2023', 'journal-title': 'Food Res Int'}
# {'issue': '1', 'key': 'pone.0321649.ref002', 'doi-asserted-by': 'crossref', 'first-page': '4349', 'DOI': '10.1038/s41467-023-40014-5', 'article-title': 'An unconventional proanthocyanidin pathway in maize', 'volume': '14', 'author': 'N Lu', 'year': '2023', 'journal-title': 'Nat Commun'}
# ...

# %%
references
# Out:
# [{'issue': 'Pt 2',
#   'key': 'pone.0321649.ref001',
#   'doi-asserted-by': 'crossref',
#   'first-page': '113390',
#   'DOI': '10.1016/j.foodres.2023.113390',
#   'article-title': 'Comprehensive evaluation of nutritional components, bioactive metabolites, and antioxidant activities in diverse sorghum (Sorghum bicolor (L.) Moench) landraces',
#   'volume': '173',
#   'author': 'KT Desta',
#   'year': '2023',
#   'journal-title': 'Food Res Int'},
#  {'issue': '1',
#   'key': 'pone.0321649.ref002',
#   'doi-asserted-by': 'crossref',
#   'first-page': '4349',
#   'DOI': '10.1038/s41467-023-40014-5',
#   'article-title': 'An unconventional proanthocyanidin pathway in maize',
#   'volume': '14',
#   'author': 'N Lu',
#   'year': '2023',
#   'journal-title': 'Nat Commun'},
#  {'issue': '10',
#   'key': 'pone.0321649.ref003',
#   'doi-asserted-by': 'crossref',
#   'first-page': '1521',
#   'DOI': '10.1080/10408398.2017.1418284',
# ...
